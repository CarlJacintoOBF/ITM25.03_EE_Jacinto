# %% [markdown]
# # 1. Coins (25 pts)

# %% [markdown]
# ### Instructions

# %% [markdown]
# Given a list of coin denominations, output the coin combination that uses the least number of coins to produce an exact sum, which ranges from 45 to 55.
#
# For example, given a list of coin denominations [1, 2, 5, 10], the coin combination that uses the least amount of coins to produce the sum 44 is 4x 10 peso coins, 0x 5 peso coins, 2x 2 peso coins, and 0x 1 peso coins.
#
# The list of coin denominations can appear in any order, and can contain any denominations; assume that they are not sorted. You may assume, however, that it only cointains integers, and always contains a coin with a denomination of 1.
#
# Output your answer in a Data Frame following the format in the example.
#
# Test your answer for the set [5, 3, 1, 11].

# %% [markdown]
# ### Example

# %% [markdown]
# **Sample Input:**

# %%
denomination_samples = [5, 3, 1, 11]

# %% [markdown]
# **Sample Output:**

# %% [markdown]
# ![Screen%20Shot%202019-07-13%20at%2011.28.22%20PM.png](attachment:Screen%20Shot%202019-07-13%20at%2011.28.22%20PM.png)

# %% [markdown]
# ### Answer
